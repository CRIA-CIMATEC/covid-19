# %% [markdown]
# # Resultados CNN1D

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import pearsonr
from tensorflow import keras

import ai_utils.metrics as ai_metrics
import matplotlib.pyplot as plt
import tensorflow as tf
import pandas as pd
import numpy as np
import pickle
import joblib
import math

# %% [markdown]
# ## Funções

# %% [markdown]
# Função para exibir os resultados para cada horizonte de predição
#
# - y_true: DataFrame com os valores verdadeiros
# - y_pred: DataFrame com os valores preditos
# - title: Título para exibição
# - xlabel: Título para o eixo x
# - ylabel: Título para o eixo y

# %%
def plot_samples(y_true, y_pred, out, title='', xlabel='', ylabel=''):
    
    plt.figure(figsize=(14, 18))
    plt.suptitle(title, fontsize=14, y=1.03)
    
    n_cols = y_true.shape[1]
    
    for col in range(n_cols):
        
        days = list(range(col+1, (col+1)+len(y_true)))
        
        plt.subplot((n_cols/4)+1, 4, col+1)
        plt.title('Previsões para t+{}'.format(col+1))
        plt.plot(days, y_true.iloc[:, col], label='Real')
        plt.plot(days, y_pred.iloc[:, col], label='Previsão')
        plt.legend()
        plt.xlabel(xlabel, fontsize=10)
        plt.ylabel(ylabel, fontsize=10)
        plt.xlim(left=days[0], right=days[-1])
        plt.xticks(np.linspace(days[0], days[-1], num=5, dtype=int))
        
    plt.tight_layout()
    plt.subplots_adjust(wspace=0.4, hspace=0.4)
    plt.savefig(out)
    plt.show()

# %% [markdown]
# Função para exibir os resultados das métricas para cada horizonte de predição
#
# - y_true: DataFrame com os valores verdadeiros
# - y_pred: DataFrame com os valores preditos

# %%
def get_metrics(y_true, y_pred):
    
    metrics = pd.DataFrame(columns=['MSE', 'RMSE', 'MAE', 'Pearson r', 'Fac2'])
    
    n_cols = y_true.shape[1]
    
    for col in range(n_cols):
        y_true_col = y_true.iloc[:, col]
        y_pred_col = y_pred.iloc[:, col]

        if y_true_col.name == y_pred_col.name:
            col_name = y_true_col.name
        else:
            print('Column name error.')
            return None

        mse = mean_squared_error(y_true_col, y_pred_col)
        rmse = mean_squared_error(y_true_col, y_pred_col, squared=False)
        mae = mean_absolute_error(y_true_col, y_pred_col)
        pearson_r = pearsonr(y_true_col, y_pred_col)[0]
        fac2 = ai_metrics.fac2(y_true_col.values, y_pred_col.values, to_numpy=True)
        metrics.loc[col_name, :] = [mse, rmse, mae, pearson_r, fac2]

    metrics.loc['Average', :] = metrics.mean()
    return metrics

# %% [markdown]
# Função para exibir os gráficos com o histórico das métricas
#
# - dict_metrics: Dict com as tabelas contendo as métricas
# - title: Título para exibição
# - xlabel: Título para o eixo x
# - ylabel: Título para o eixo y

# %%
def plot_metrics(dict_metrics, out, title='', xlabel='', ylabel=''):
    
    plt.figure(figsize=(14, 12))
    plt.suptitle(title, fontsize=14, y=0.935)
    
    keys = list(dict_metrics.keys())
    key_0 = keys[0]
    metrics_df_0 = dict_metrics[key_0]
    metrics_names = metrics_df_0.columns
    time_steps = list(range(1, metrics_df_0.shape[0]))
    
    for col, metric_name in enumerate(metrics_names):
        
        plt.subplot(3, 2, col+1)
        
        for key in dict_metrics.keys():
            
            metrics_df = dict_metrics[key]
            plt.plot(time_steps, metrics_df.iloc[0:-1, col], marker='o', label=key)
        
        plt.title('{} para cada horizonte de previsão'.format(metric_name))
        plt.legend()
        plt.xlabel('Dias a frente', fontsize=10)
        plt.ylabel(metric_name, fontsize=10)
        plt.xlim(left=time_steps[0], right=time_steps[-1])
        plt.xticks(np.linspace(time_steps[0], time_steps[-1], num=5, dtype=int))
        
    plt.subplots_adjust(wspace=0.2, hspace=0.4)
    plt.savefig(out)
    plt.show()

# %% [markdown]
# Função para exibir o scatter plot de cada horizonte de predição
#
# - title: Título para exibição
# - xlabel: Título para o eixo x
# - ylabel: Título para o eixo y

# %%
def plot_scatter(y_true, y_pred, out, title=''):
    
    plt.figure(figsize=(14, 18))
    plt.suptitle(title, fontsize=14, y=1.03)
    
    n_cols = y_true.shape[1]
    
    for col in range(n_cols):
        
        max_val = max(y_true.iloc[:, col].max(), y_pred.iloc[:, col].max())
        min_val = min(y_true.iloc[:, col].min(), y_pred.iloc[:, col].min())
                
        max_lim = max_val + max_val*0.05
        max_lim = math.ceil(max_lim)
        
        ndigits = len(str(max_lim))
        max_lim = int(math.ceil(max_lim / (10.0**(ndigits-2)) )) * (10.0**(ndigits-2))
        
        min_lim = min_val - max_val*0.05
        min_lim = max(0, min_lim)
        
        plt.subplot((n_cols/4)+1, 4, col+1)
        plt.title('Previsões para t+{}'.format(col+1))
        plt.scatter(y_true.iloc[:, col], y_pred.iloc[:, col])
        plt.xlabel('Real', fontsize=10)
        plt.ylabel('Previsão', fontsize=10)
        
        plt.xlim(left=min_lim, right=max_lim)
        plt.ylim(top=max_lim, bottom=min_lim)
        
        plt.xticks(np.linspace(min_lim, max_lim, num=5, dtype=int))
        plt.yticks(np.linspace(min_lim, max_lim, num=5, dtype=int))

        plt.plot([min_lim, max_lim], [min_lim, max_lim])
        
    plt.tight_layout()
    plt.subplots_adjust(wspace=0.4, hspace=0.4)
    plt.savefig(out)
    plt.show()

# %% [markdown]
# Função para preparar a estrutura de uma respectiva região do DataFrame para entrada na rede
#
# - key: chave considerada para agrupar, isoladamente, cada série
# - region_data: DataFrame com as séries
# - look_back: Tamanho do look back
# - look_forward: Tamanho para o look forward
# - x_columns: Colunas consideradas para entrada no modelo
# - y_columns: Colunas consideradas para o target do modelo
# - gen_x & gen_y: habilitam a geração de cada output

# %%
def generate_single_region_dataset(key, region_data, look_back, look_forward, x_columns, y_columns=None, gen_x=True, gen_y=True):
    
    # Check region dataframe
    if region_data is None:
        print('generate_single_region_dataset error: Region data is None!')
        return (None, None)
    
    # Check number of regions
    if len(region_data[key].unique()) > 1:
        print('generate_single_region_dataset error: More than one region in the dataframe!')
        return (None, None)
    else:
        region_name = region_data[key].unique()[0]
    
    # Drop 'Region' column
    region_data = region_data.drop(columns=key)
    
    # Check the number of samples available to
    # generate the look back and look forward windows
    if len(region_data) < (look_back + look_forward):
        print('generate_single_region_dataset error: Not enough samples '+
              'in {} to generate the windows!'.format(region_name))
        return (None, None)
    
    n_samples = len(region_data) - look_back - look_forward + 1

    var_names = x_columns
    
    # Generate inputs
    if gen_x:
        inputs = pd.DataFrame()
        
        for i in range(n_samples):
            input_window = region_data.T.iloc[:, i:i+look_back]
            wide_input_sample = pd.DataFrame()
            
            for var in var_names:
                var_input_sample = input_window.loc[var:var, :]
                var_input_sample.columns = ['{}_t{}'.format(var, a) for a in range(1-look_back, 1)]
                var_input_sample = var_input_sample.reset_index(drop=True)
                wide_input_sample = pd.concat([wide_input_sample, var_input_sample], axis='columns')
                
            inputs = pd.concat([inputs, wide_input_sample], axis='index')
            
        # Insert region name
        #inputs.insert(loc=0, column=key, value=region_name)
        # Reset index
        inputs = inputs.reset_index(drop=True)

    # Generate outputs
    if gen_y:
        
        if y_columns is None:
            print('generate_single_region_dataset error: Need to specify column labels!')
            return (None, None)
        
        var_names = y_columns
        outputs = pd.DataFrame()
        
        for i in range(n_samples):
            output_window = region_data.T.iloc[:, i+look_back : i+look_back+look_forward]
            wide_output_sample = pd.DataFrame()

            for var in var_names:
                var_output_sample = output_window.loc[var:var, :]
                var_output_sample.columns = ['{}_t+{}'.format(var, a) for a in range(1, look_forward+1)]
                var_output_sample = var_output_sample.reset_index(drop=True)
                wide_output_sample = pd.concat([wide_output_sample, var_output_sample], axis='columns')

            outputs = pd.concat([outputs, wide_output_sample], axis='index')
        
        # Insert region name
        #outputs.insert(loc=0, column=key, value=region_name)
        # Reset index
        outputs = outputs.reset_index(drop=True)
        
    if gen_x and gen_y:
        return (inputs, outputs)
    elif gen_x:
        return (inputs, None)
    elif gen_y:
        return (None, outputs)

# %% [markdown]
# Função para preparar a estrutura do DataFrame para entrada na rede
#
# - key: chave considerada para agrupar, isoladamente, cada série
# - region_data: DataFrame com as séries
# - look_back: Tamanho do look back
# - look_forward: Tamanho para o look forward
# - x_columns: Colunas consideradas para entrada no modelo
# - y_columns: Colunas consideradas para o target do modelo
# - gen_x & gen_y: habilitam a geração de cada output

# %%
def generate_regions_dataset(key, regions_data, look_back, look_forward, x_columns, y_columns=None, 
                             gen_x=True, gen_y=True):
    
    regions_names = regions_data[key].unique()
    
    all_regions_x = pd.DataFrame()
    all_regions_y = pd.DataFrame()
    
    for region_name in regions_names:
        
        region_data = regions_data[regions_data[key]==region_name]
        
        region_x, region_y = generate_single_region_dataset(key,
            region_data, look_back=look_back, look_forward=look_forward, x_columns=x_columns, y_columns=y_columns,
            gen_x=gen_x, gen_y=gen_y
        )
        
        if not (region_x is None):
            all_regions_x = pd.concat([all_regions_x, region_x])
            all_regions_x = all_regions_x.reset_index(drop=True)
            
        if not (region_y is None):
            all_regions_y = pd.concat([all_regions_y, region_y])
            all_regions_y = all_regions_y.reset_index(drop=True)
    
    if gen_x and gen_y:
        return (all_regions_x, all_regions_y)
    elif gen_x:
        return (all_regions_x, None)
    elif gen_y:
        return (None, all_regions_y)

# %% [markdown]
# Função para exibir o gráfico histórico de loss do treinamento
#
# - filepath: caminho para o arquivo com o history

# %%
def plot_history_from_file(filepath, out):
    
    with open(filepath, 'rb') as f:
        history = pickle.load(f)
    
    plt.figure(figsize=[10, 6])
    plt.xlabel('Epoch')
    plt.ylabel('Mean Squared Error')
    plt.plot(range(1, len(history['loss'])+1), history['loss'], label='Train Loss')
    plt.plot(range(1, len(history['loss'])+1), history['val_loss'], label = 'Validation loss')
    
    plt.legend()
    plt.savefig(out)
    plt.show()

# %% [markdown]
# Função para realizar a inferência
#
# - model: função para carregar o modelo ou o próprio modelo
# - lookback: lookback utilizado nos dados
# - build_model: False se um modelo for passado em `model`
# - x_train, y_train: None se o build_model for False
# - step_inference: total de step para previsão final após inferência
# - data_reshape_func: função caso seja feito algum reshape sobre os dados de teste
# - reshape_train, reshape_val: True caso deseje aplicar o mesmo reshape no conjunto de treinamento e validação
# - trainable: True caso deseje realizar um novo treinamento do modelo
# - step: tamanho atual do Look forward
# - x_val, y_val: dados do conjunto de validação
# - x_test, y_test: dados do conjunto de teste
# - shuffle, batch_size, epochs, verbose: utilizando para treinamento

# %%
def nn_inference(model, lookback, position, build_model=True, x_train= None, y_train = None, step_inference=30, data_reshape_func=None,
                 reshape_train=False, reshape_val=False, trainable =True, step=10, x_val = None, y_val = None,
                 x_test=None, y_test=None, shuffle=False, batch_size=10, epochs=10, verbose=1):
    
    if step_inference % step != 0:
        print('Error - timesteps % inference steps != 0')
        return None, None, None
    
    if build_model == True:
        modelo = model()
    else:
        modelo = model
    
    if reshape_train == True:
        x_train = data_reshape_func(x_train)
    else:
        pass
        #print("Warning - You are not reshaping the x_train!")
    
    history = None
    if trainable == True:
        if x_train is None or y_train is None:
            print('Error - Trainable Model but no x_train or y_train')
            return None, None, None
        if x_val is not None and y_val is not None:
            if reshape_val == True:
                x_val = data_reshape_func(x_val)
            else:
                pass
                #print("Warning - You are not reshaping the x_val!")
            history = modelo.fit(x_train, y_train, validation_data=(x_val, y_val), shuffle=shuffle, batch_size = batch_size, epochs = epochs, verbose=verbose)
        else:
            history = modelo.fit(x_train, y_train, shuffle=shuffle ,batch_size = batch_size, epochs = epochs, verbose=verbose)
        
    if x_test is not None:
        step_list = [] #np.empty(int(y_train.shape[1] % step))
        #predicao_desnormalizado = []
        #print(x_test)
        for w in range(int(step_inference / step)):
            if w == 0:
                next_step = np.copy(x_test)
                new_x_test = np.copy(x_test)
                if data_reshape_func is not None:
                    new_x_test = data_reshape_func(x_test)
                else:
                    print("Warning - You are not reshaping the x_test!")
                
                #print(new_x_test.shape)
                step_list.append(modelo.predict(new_x_test))
                #predicao_desnormalizado.append(normalizador_y.inverse_transform(predicao_t10))
            else:
                new_step = np.copy(x_test)
                for i in range(new_step.shape[0]):
                        if lookback <= step:
                            for j in range(lookback):
                                new_step[i, j+position] = step_list[w-1][i, -lookback + j]
                        else:
                            for j in range(step):
                                new_step = np.copy(next_step)
                                new_step[i, j+position+(lookback-step)] = step_list[w-1][i, -step + j]
                                next_step[i, j+position+(lookback-(2*step))] = step_list[w-1][i, -step + j]
                
                new_x_test = np.copy(new_step)
                if data_reshape_func is not None:
                    new_x_test = data_reshape_func(new_step)
                
                step_list.append(modelo.predict(new_x_test))
                #predicao_t20_desnormalizado = normalizador_y.inverse_transform(predicao_t20)
        
        predicao = None
        for k in range(len(step_list) - 1):
            if k == 0:
                predicao = np.append(step_list[k], step_list[k+1], axis=1)
            else:
                predicao = np.append(predicao, step_list[k+1], axis=1)
    
        return history, predicao, modelo
    
    return history, None, modelo

# %% [markdown]
# ## Variáveis

# %% [markdown]
# Colunas dos dados

# %%
# COLS = [
#     'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'Confirmed',
#     'Country/Region', 'Date', 'Deaths', 'Recovered', 'cases_day', 'end',
#     'estagio', 'grocery_and_pharmacy', 'parks', 'peak', 'postinflex',
#     'preinflex', 'residential', 'retail_and_recreation', 'transit_stations',
#     'workplaces'
# ]
# COLS_OHE = [
#     'C1.0', 'C1.1', 'C2.0', 'C2.1', 'C3.0', 'C3.1', 'C4.0', 'C4.1', 'C5.0',
#     'C5.1', 'C6.0', 'C6.1', 'C7.0', 'C7.1', 'C8.0', 'C8.1', 'Confirmed',
#     'Country/Region', 'Date', 'Deaths', 'estagio', 'grocery_and_pharmacy',
#     'parks', 'peak', 'postinflex', 'preinflex', 'residential',
#     'retail_and_recreation', 'transit_stations', 'workplaces'
# ]

# %% [markdown]
# Colunas a serem utilizadas para prever casos confirmados e mortes

# %%
COLS_WD = [
    'C1.1', 'C2.1', 'C3.1', 'C4.1', 'C5.1', 'C6.1', 'C7.1', 'C8.1', 'Confirmed', 'Deaths'
]

# COLS_WD = [
#     'C1', 'C2', 'C3', 'C4', 'C5', 'C6', 'C7', 'C8', 'Confirmed',
#     'Deaths', 'grocery_and_pharmacy', 'parks', 'residential',
#     'retail_and_recreation', 'transit_stations', 'workplaces'
# ]

# %% [markdown]
# Caminho base

# %%
BASE = 'results/confirmed/lb25_lf10_wdmc_new'

# %% [markdown]
# Caminho para os DataFrame reestruturados

# %%
F_XTRAIN = f'{BASE}/infe/x_train.csv'
F_YTRAIN = f'{BASE}/infe/y_train.csv'

F_XTEST = f'{BASE}/infe/x_test.csv'
F_YTEST = f'{BASE}/infe/y_test.csv'

F_XVAL = f'{BASE}/infe/x_val.csv'
F_YVAL = f'{BASE}/infe/y_val.csv'

# %% [markdown]
# Caminho para o scaler

# %%
F_XSCALER = f'{BASE}/infe/x_scale.joblib'
F_YSCALER = f'{BASE}/infe/y_scale.joblib'

# %% [markdown]
# Caminho para os modelos

# %%
FM_AIS = f'{BASE}/models_pop8_inte8/final_weights_ais_best_model.h5'
FM_NSGAII = f'{BASE}/models_pop8_inte8/final_weights_nsgaii_best_model.h5'
FM_PSO = f'{BASE}/models_pop8_inte8/final_weights_pso_best_model.h5'
FM_RSEARCH = f'{BASE}/models_pop8_inte8/final_weights_randomsearch_best_model.h5'

# %% [markdown]
# Caminho para o History

# %%
HISTORY = f'{BASE}/models_pop8_inte8/history_nsgaii_best_model.pk'

# %% [markdown]
# Caminho para os dados brutos

# %%
# [train|test|val]_mundial_estadual[_OHE]_model[_peak]_20200629
RAW_TRAIN = 'raw_datas/train_mundial_estadual_OHE_model_20200629.csv'
RAW_TEST = 'raw_datas/test_mundial_estadual_OHE_model_20200629.csv'
RAW_VAL = 'raw_datas/val_mundial_estadual_OHE_model_20200629.csv'

# %% [markdown]
# Configuração de look-back e look-forward

# %%
LB = 25
LF = 30

# %% [markdown]
# ## Steps

# %% [markdown]
# ### Pré-processamento para simulação

# %% [markdown]
# Carregando dados brutos

# %%
train = pd.read_csv(RAW_TRAIN)
test = pd.read_csv(RAW_TEST)
val = pd.read_csv(RAW_VAL)

# %% [markdown]
# Colunas

# %%
#Colunas para usar no X
x_columns = COLS_WD
#Colunas para usar no Y
y_columns = ['Confirmed']

# %% [markdown]
# Listas para armazenar os países para inferência

# %%
list_train = []
list_val = []
list_test = []

# %% [markdown]
# Inicializando o scaler

# %%
x_base, y_base = generate_regions_dataset(
    key="Country/Region",
    regions_data=train,
    look_back=LB,
    look_forward=LF,
    x_columns=x_columns,
    y_columns=y_columns
)

x_scaler = MinMaxScaler(feature_range=(0, 1))
y_scaler = MinMaxScaler(feature_range=(0, 1))

x_scaler.fit(x_base)
y_scaler.fit(y_base)
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %% [markdown]
# Gerando o x e y para treinamento

# %%
for c in train['Country/Region'].unique():
    aux = train.loc[train['Country/Region'] == c]
    x_train, y_train = generate_regions_dataset(
        key="Country/Region",
        regions_data=aux,
        look_back=LB,
        look_forward=LF,
        x_columns=x_columns,
        y_columns=y_columns
    )
    try:
        x_train = x_scaler.transform(x_train)
        y_train = y_scaler.transform(y_train)
        # removes columns T+11..T+30
#         y_train = np.delete(y_train, np.s_[10:LF], axis=1)
        list_train.append([x_train, y_train])
    except Exception as e:
        print(f'[ERROR] Country {c}: {e}')

# %% [markdown]
# Gerando o x e y para validação

# %%
for c in val['Country/Region'].unique():
    aux = val.loc[val['Country/Region'] == c]
    x_val, y_val = generate_regions_dataset(
        key="Country/Region",
        regions_data=aux,
        look_back=LB,
        look_forward=LF,
        x_columns=x_columns,
        y_columns=y_columns
    )
    try:
        x_val = x_scaler.transform(x_val)
        y_val = y_scaler.transform(y_val)
        # removes columns T+11..T+30
#         y_val = np.delete(y_val, np.s_[10:LF], axis=1)
        list_val.append([x_val, y_val])
    except Exception as e:
        print(f'[ERROR] Country {c}: {e}')
# Out:
# generate_single_region_dataset error: Not enough samples in Tajikistan to generate the windows!
# [ERROR] Country Tajikistan: at least one array or dtype is required

# %% [markdown]
# Gerando o x e y para teste

# %%
for c in test['Country/Region'].unique():
    aux = test.loc[test['Country/Region'] == c]
    x_test, y_test = generate_regions_dataset(
        key="Country/Region",
        regions_data=aux,
        look_back=LB,
        look_forward=LF,
        x_columns=x_columns,
        y_columns=y_columns
    )
    try:
        x_test = x_scaler.transform(x_test)
        y_test = y_scaler.transform(y_test)
        # removes columns T+11..T+30
#         y_test = np.delete(y_test, np.s_[10:LF], axis=1)
        list_test.append([x_test, y_test])
    except Exception as e:
        print(f'[ERROR] Country {c}: {e}')

# %% [markdown]
# Salvando colunas do shape

# %%
x_cols = x_base.columns
y_cols = y_base.columns

# %% [markdown]
# Armazenando o scaler

# %%
# Descomente para salvar
joblib.dump(x_scaler, F_XSCALER)
joblib.dump(y_scaler, F_YSCALER)

# %%
# pd.DataFrame(x_train_scaled, columns=x_cols).to_csv(F_XTRAIN, index=False)
# pd.DataFrame(y_train_scaled, columns=y_cols).to_csv(F_YTRAIN, index=False)

# pd.DataFrame(x_val_scaled, columns=x_cols).to_csv(F_XVAL, index=False)
# pd.DataFrame(y_val_scaled, columns=y_cols).to_csv(F_YVAL, index=False)

# Descomente para salvar (em regra não será necessário salvar o teste)
# pd.DataFrame(x_test_scaled, columns=x_cols).to_csv(F_XTEST, index=False)
# pd.DataFrame(y_test_scaled, columns=y_cols).to_csv(F_YTEST, index=False)

# %% [markdown]
# ## Avaliação

# %% [markdown]
# Carregando os dados
#
# _Opcional, caso já esteja carregado_

# %%
# x_train_scaled = pd.read_csv(F_XTRAIN)
# x_test_scaled = pd.read_csv(F_XTEST)
# x_val_scaled = pd.read_csv(F_XVAL)

# %% [markdown]
# Carregando scaler e normalizando os dados
#
# _Opcional, caso já esteja carregado_

# %%
# x_scaler = joblib.load(F_XSCALER)
# y_scaler = joblib.load(F_YSCALER)

# %% [markdown]
# Carregando modelo

# %%
try:
    model = keras.models.load_model(
        FM_NSGAII, # FM_AIS, FM_NSGAII, FM_PSO, FM_RSEARCH
        custom_objects={
            'R_squared':ai_metrics.R_squared,
            'pearson_r':ai_metrics.pearson_r,
            'fac2':ai_metrics.fac2
        }
    )
    print("Model found!")
except OSError:
    print("Model not found!")
# Out:
# Model found!

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 250, 1)]          0
# _________________________________________________________________
# average_pooling1d_1 (Average (None, 250, 1)            0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 250, 33)           99
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 250, 33)           2211
# _________________________________________________________________
# average_pooling1d_2 (Average (None, 250, 33)           0
# _________________________________________________________________
# average_pooling1d_3 (Average (None, 250, 33)           0
# _________________________________________________________________
# conv1d_6 (Conv1D)            (None, 250, 33)           2211
# _________________________________________________________________
# average_pooling1d_4 (Average (None, 250, 33)           0
# _________________________________________________________________
# average_pooling1d_5 (Average (None, 250, 33)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8250)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                82510
# =================================================================
# Total params: 87,031
# Trainable params: 87,031
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Histórico

# %%
plot_history_from_file(
    HISTORY, f'{BASE}/infe/history_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.png'
)

# %% [markdown]
# ### Resultados com todo conjunto de dados (Inferência)

# %% [markdown]
# Treinamento

# %%
results_train = []

for i in range(len(list_train)):
    _, inference, _ = nn_inference(
        model,
        LB,
        200,
        build_model=False,
        x_test = list_train[i][0],
        y_test = list_train[i][1],
        trainable=False
    )
    results_train.append(inference)
# Out:
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!

# %%
obs_train = np.copy(list_train[0][1])
for i in range(len(results_train) - 1):
    if i == 0:
        obs_train = np.append(list_train[i][1], list_train[i+1][1], axis=0)
    else:
        obs_train = np.append(obs_train, list_train[i+1][1], axis=0)

# %%
prediction_train = np.copy(results_train[0])
for i in range(len(results_train) - 1):
    if i == 0:
        prediction_train = np.append(results_train[i], results_train[i + 1], axis=0)
    else:
        prediction_train = np.append(prediction_train, results_train[i + 1], axis=0)

# %%
y_true = np.copy(obs_train)
y_pred = np.copy(prediction_train)

y_true = y_scaler.inverse_transform(y_true)
y_pred = y_scaler.inverse_transform(y_pred)

# %%
y_true = pd.DataFrame(y_true, columns=y_cols)
y_pred = pd.DataFrame(y_pred, columns=y_cols)
y_pred.to_csv(f'{BASE}/infe/train_pred_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.csv')
train_metrics = get_metrics(y_true, y_pred)
train_metrics.to_csv(
    f'{BASE}/infe/train_metrics_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.csv'
)
train_metrics
# Out:
#                         MSE     RMSE      MAE Pearson r      Fac2
# Confirmed_t+1        726178  852.161  402.678  0.974734   0.22278
# Confirmed_t+2        949622  974.485  363.807  0.965673  0.274122
# Confirmed_t+3   1.03935e+06  1019.49  325.911  0.963199  0.331071
# Confirmed_t+4   1.12809e+06  1062.12  355.709  0.959777  0.313957
# Confirmed_t+5    1.2176e+06  1103.45  385.927  0.956962   0.30776
# Confirmed_t+6   1.38567e+06  1177.15  422.787  0.951297  0.276483
# Confirmed_t+7   1.67248e+06  1293.24    563.7  0.941929  0.202125
# Confirmed_t+8   1.93281e+06  1390.25  507.816  0.931939  0.236353
# Confirmed_t+9   2.14859e+06  1465.81  593.304  0.924813  0.215403
# Confirmed_t+10  2.31715e+06  1522.22  516.867  0.918904  0.262614
# Confirmed_t+11  2.82481e+06  1680.72  557.345  0.899751  0.228681
# Confirmed_t+12  2.88723e+06  1699.19   508.33  0.898384  0.249336
# Confirmed_t+13  3.09501e+06  1759.26  471.307  0.892782  0.291236
# Confirmed_t+14  3.16303e+06  1778.49  499.949  0.889642  0.272057
# Confirmed_t+15  3.37216e+06  1836.34  548.309  0.881386  0.259664
# Confirmed_t+16  3.52417e+06  1877.28  567.014  0.875162  0.249631
# Confirmed_t+17  3.61256e+06  1900.67  696.155  0.871485  0.205075
# Confirmed_t+18  3.56195e+06  1887.31  645.981  0.872495  0.227501
# Confirmed_t+19  3.44573e+06  1856.27  716.728  0.876534   0.20596
# Confirmed_t+20  3.46711e+06  1862.02  638.169  0.875483  0.231042
# Confirmed_t+21  4.00161e+06   2000.4  661.052  0.853933  0.221304
# Confirmed_t+22  4.13463e+06  2033.38  632.438  0.848893  0.242254
# Confirmed_t+23  4.24481e+06  2060.29  605.481  0.846257  0.242254
# Confirmed_t+24  4.16486e+06   2040.8  629.581  0.848623  0.228091
# Confirmed_t+25  4.05746e+06  2014.31  658.053  0.851508  0.239599
# Confirmed_t+26  4.06202e+06  2015.44  673.204  0.851487  0.231337
# Confirmed_t+27  4.09552e+06  2023.74  791.692  0.849895  0.214518
# Confirmed_t+28  4.15994e+06  2039.59  758.228   0.84823   0.22573
# Confirmed_t+29  4.37446e+06  2091.52  835.821  0.840957  0.211272
# Confirmed_t+30   4.6274e+06  2151.14   774.09  0.835022  0.214222
# Average          2.9798e+06  1682.28  576.914  0.893238  0.244448

# %% [markdown]
# Validação

# %%
results_val = []

for i in range(len(list_val)):
    _, inference, _ = nn_inference(
        model,
        LB,
        200,
        build_model=False,
        x_test = list_val[i][0],
        y_test = list_val[i][1],
        trainable=False
    )
    results_val.append(inference)
# Out:
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!

# %%
obs_val = np.copy(list_val[0][1])
for i in range(len(results_val) - 1):
    if i == 0:
        obs_val = np.append(list_val[i][1], list_val[i+1][1], axis=0)
    else:
        obs_val = np.append(obs_val, list_val[i+1][1], axis=0)

# %%
prediction_val = np.copy(results_val[0])
for i in range(len(results_val) - 1):
    if i == 0:
        prediction_val = np.append(results_val[i], results_val[i + 1], axis=0)
    else:
        prediction_val = np.append(prediction_val, results_val[i + 1], axis=0)

# %%
y_true = np.copy(obs_val)
y_pred = np.copy(prediction_val)

y_true = y_scaler.inverse_transform(y_true)
y_pred = y_scaler.inverse_transform(y_pred)

# %%
y_true = pd.DataFrame(y_true, columns=y_cols)
y_pred = pd.DataFrame(y_pred, columns=y_cols)
y_pred.to_csv(f'{BASE}/infe/val_pred_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.csv')
val_metrics = get_metrics(y_true, y_pred)
val_metrics.to_csv(
    f'{BASE}/infe/val_metrics_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.csv'
)
val_metrics
# Out:
#                         MSE     RMSE      MAE Pearson r      Fac2
# Confirmed_t+1        659828  812.298   463.26  0.825764  0.290909
# Confirmed_t+2        665185  815.589  419.546  0.813527  0.330303
# Confirmed_t+3        598946  773.916  363.225  0.812812   0.36835
# Confirmed_t+4        668784  817.792   398.02  0.794694  0.359933
# Confirmed_t+5        757970  870.615  455.546  0.776588  0.325589
# Confirmed_t+6        834389  913.449   492.47  0.763402  0.314478
# Confirmed_t+7   1.04457e+06  1022.04  642.932   0.74023  0.250168
# Confirmed_t+8        961076  980.345  576.546  0.724259  0.275758
# Confirmed_t+9   1.11646e+06  1056.63  663.207  0.695544  0.255556
# Confirmed_t+10  1.00202e+06  1001.01  561.691  0.692528  0.291582
# Confirmed_t+11  1.15467e+06  1074.56  596.713  0.683462  0.256229
# Confirmed_t+12  1.22682e+06  1107.62  573.642  0.661475  0.272054
# Confirmed_t+13  1.13457e+06  1065.16  513.039  0.653889  0.261953
# Confirmed_t+14  1.22749e+06  1107.92  542.505  0.634871  0.274747
# Confirmed_t+15  1.35568e+06  1164.34  610.661  0.606723  0.242761
# Confirmed_t+16  1.39121e+06  1179.49  625.497  0.595883  0.239394
# Confirmed_t+17  1.65066e+06  1284.78  772.346  0.565674  0.226263
# Confirmed_t+18  1.62207e+06   1273.6  729.171  0.551721  0.232323
# Confirmed_t+19  1.75653e+06  1325.34  810.787  0.531394  0.227273
# Confirmed_t+20  1.54973e+06  1244.88  699.217  0.538507   0.22963
# Confirmed_t+21  1.71618e+06  1310.03  718.235  0.512829  0.216835
# Confirmed_t+22  1.81509e+06  1347.25  701.313  0.492212  0.215825
# Confirmed_t+23  1.65932e+06  1288.15  642.308   0.49641   0.20505
# Confirmed_t+24  1.75727e+06  1325.62  673.345  0.484502  0.220539
# Confirmed_t+25  1.89414e+06  1376.28  734.751  0.457486  0.196633
# Confirmed_t+26  1.91541e+06  1383.98  747.158  0.450662  0.194276
# Confirmed_t+27  2.17837e+06  1475.93  883.706  0.420724  0.194613
# Confirmed_t+28   2.1847e+06  1478.07  845.768  0.403444  0.192929
# Confirmed_t+29  2.32413e+06  1524.51  927.882  0.380377  0.184175
# Confirmed_t+30  2.13334e+06   1460.6  820.806  0.382587  0.191919
# Average         1.39855e+06  1162.06  640.176  0.604806  0.251268

# %% [markdown]
# Teste

# %%
results_test = []

for i in range(len(list_test)):
    _, inference, _ = nn_inference(
        model,
        LB,
        200,
        build_model=False,
        x_test = list_test[i][0],
        y_test = list_test[i][1],
        trainable=False
    )
    results_test.append(inference)
# Out:
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!
# Warning - You are not reshaping the x_test!

# %%
obs_test = np.copy(list_test[0][1])
for i in range(len(results_test) - 1):
    if i == 0:
        obs_test = np.append(list_test[i][1], list_test[i+1][1], axis=0)
    else:
        obs_test = np.append(obs_test, list_test[i+1][1], axis=0)

# %%
prediction_test = np.copy(results_test[0])
for i in range(len(results_test) - 1):
    if i == 0:
        prediction_test = np.append(results_test[i], results_test[i + 1], axis=0)
    else:
        prediction_test = np.append(prediction_test, results_test[i + 1], axis=0)

# %%
y_true = np.copy(obs_test)
y_pred = np.copy(prediction_test)

y_true = y_scaler.inverse_transform(y_true)
y_pred = y_scaler.inverse_transform(y_pred)

# %%
y_true = pd.DataFrame(y_true, columns=y_cols)
y_pred = pd.DataFrame(y_pred, columns=y_cols)
y_pred.to_csv(f'{BASE}/infe/test_pred_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.csv')
test_metrics = get_metrics(y_true, y_pred)
test_metrics.to_csv(
    f'{BASE}/infe/test_metrics_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.csv'
)
test_metrics
# Out:
#                         MSE     RMSE      MAE Pearson r      Fac2
# Confirmed_t+1        950911  975.147  519.678  0.905027  0.300931
# Confirmed_t+2   1.06805e+06  1033.47  493.114  0.893526  0.332989
# Confirmed_t+3   1.13672e+06  1066.17  451.751  0.887891  0.391934
# Confirmed_t+4   1.22194e+06  1105.42  490.818   0.88378  0.361944
# Confirmed_t+5   1.33702e+06   1156.3  551.035  0.882767  0.338159
# Confirmed_t+6   1.55451e+06   1246.8  585.693  0.877395  0.320579
# Confirmed_t+7   1.98241e+06  1407.98   754.71  0.861335  0.256463
# Confirmed_t+8   2.53695e+06  1592.78  724.235  0.848065  0.287487
# Confirmed_t+9   2.83509e+06  1683.77  828.357  0.829909  0.247156
# Confirmed_t+10  3.03766e+06  1742.89  761.131  0.815422  0.284385
# Confirmed_t+11  3.30618e+06  1818.29  769.067  0.818818   0.27818
# Confirmed_t+12  3.65476e+06  1911.74  764.871    0.8158  0.280248
# Confirmed_t+13  4.20734e+06  2051.18  736.633  0.815816   0.32575
# Confirmed_t+14  4.63567e+06  2153.06   793.85  0.810427  0.305067
# Confirmed_t+15  5.21098e+06  2282.76  880.113  0.793817  0.257497
# Confirmed_t+16  5.59509e+06  2365.39  896.505  0.779067  0.262668
# Confirmed_t+17  5.88958e+06  2426.85  1054.12  0.763048  0.216132
# Confirmed_t+18  6.41057e+06  2531.91  1028.84  0.766402  0.234747
# Confirmed_t+19  6.98436e+06  2642.79  1149.93  0.767021   0.20062
# Confirmed_t+20  7.68486e+06  2772.16  1090.26   0.76554  0.222337
# Confirmed_t+21  8.20035e+06  2863.63  1082.73  0.755294   0.23061
# Confirmed_t+22  8.78528e+06     2964  1080.48  0.733113  0.240951
# Confirmed_t+23  9.41155e+06  3067.82   1054.3  0.719411  0.252327
# Confirmed_t+24  9.61277e+06  3100.45  1101.86  0.713911  0.239917
# Confirmed_t+25  1.02559e+07  3202.48  1185.37  0.720153  0.226474
# Confirmed_t+26  1.10143e+07  3318.77  1221.87  0.718245  0.232678
# Confirmed_t+27  1.14252e+07  3380.12  1375.88    0.7035  0.194416
# Confirmed_t+28  1.35343e+07  3678.91  1372.61  0.703047  0.211996
# Confirmed_t+29  1.44261e+07  3798.18  1480.44  0.693972  0.197518
# Confirmed_t+30  1.52343e+07  3903.12  1411.89  0.676536  0.219235
# Average         6.10469e+06  2308.14  923.072  0.790602  0.265047

# %% [markdown]
# Todos resultados

# %%
dict_metrics = {
    'Treinamento': train_metrics,
    'Validação': val_metrics,
    'Teste': test_metrics
}
plot_metrics(
    dict_metrics,
    title='Métricas para cada horizonte de previsão do número de mortos em cada partição de dados',
    out=f'{BASE}/infe/metrics_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.png'
)

# %% [markdown]
# ---

# %% [markdown]
# Avaliando para o LOCALE

# %%
LOCALE = 'Brazil'

# %%
target = test[test['Country/Region'] == LOCALE].copy()

# %% [markdown]
# Alternativa adicionando o dia de pandemia

# %%
# Descomente para utilizar
# f1 = target['Country/Region'] == v
# target.loc[f1, 'day'] = range(1,len(target[f1])+1)

# %% [markdown]
# Gerando o x e y

# %%
x_target, y_target = generate_regions_dataset(
    key="Country/Region",
    regions_data=target,
    look_back=LB,
    look_forward=LF,
    x_columns=x_columns,
    y_columns=y_columns
)

# %% [markdown]
# Normalizando para predição

# %%
x_target_scaled = x_scaler.transform(x_target)
y_target_scaled = y_scaler.transform(y_target)

# %% [markdown]
# Predição e avaliação

# %%
_, inference, _ = nn_inference(
    model,
    LB,
    200,
    build_model=False,
    x_test = x_target_scaled,
    y_test = y_target_scaled,
    trainable=False
)

# %%
target_pred = y_scaler.inverse_transform(inference)

# %%
y_pred = pd.DataFrame(target_pred, columns=y_cols)
target_metrics = get_metrics(y_target, y_pred)

# %% [markdown]
# Salvando o resultado da predição

# %%
y_pred.to_csv(f'{BASE}/infe/target_pred_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.csv')

# %% [markdown]
# Gráfico com as métricas de predição

# %%
dict_target = {LOCALE: target_metrics}
plot_metrics(
    dict_target,
    title=f'Métricas para cada horizonte de previsão do número de mortos no {LOCALE}',
    out=f'{BASE}/infe/metrics_test_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.png'
)

# %% [markdown]
# Gráficos de dispersão para cada horizonte de predição no Brasil

# %%
plot_scatter(
    y_target,
    y_pred,
    title=f'Gráficos de dispersão do número de mortos no {LOCALE}',
    out=f'{BASE}/infe/scatter_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.png'
)

# %% [markdown]
# Gráficos das previsões para cada horizonte de previsão no Brasil.

# %%
# Samples para peak, pre|post inflex (descomente para utilizar)
# def plot_samples(y_true, y_pred, out, title='', xlabel='', ylabel=''):
    
#     plt.figure(figsize=(15, 5))
#     plt.suptitle(title, fontsize=14, y=1.03)
    
#     n_cols = y_true.shape[1]
    
#     for col in range(n_cols):
        
#         days = list(range(col+1, (col+1)+len(y_true)))
        
#         plt.subplot((n_cols/4)+1, 3, col+1) # necessário alterar a quantidade de colunas dependendo do tamanho do target
#         plt.title('Previsões para {}'.format(y_pred.columns[col]))
#         plt.plot(days, y_true.iloc[:, col], label='Real')
#         plt.plot(days, y_pred.iloc[:, col], label='Previsão')
#         plt.legend()
#         plt.xlabel(xlabel, fontsize=10)
#         plt.ylabel(ylabel, fontsize=10)
#         plt.xlim(left=days[0], right=days[-1])
#         plt.xticks(np.linspace(days[0], days[-1], num=5, dtype=int))
        
#     plt.tight_layout()
#     plt.subplots_adjust(wspace=0.4, hspace=0.4)
#     plt.savefig(out)
#     plt.show()

plot_samples(
    y_target,
    y_pred,
    title=f'Previsão do número de mortos no {LOCALE}',
    xlabel='Dia',
    ylabel='Quantidade de mortos',
    out=f'{BASE}/infe/predict_{"_".join(y_columns)}_lb{LB}_lf{LF}_infe.png'
)
